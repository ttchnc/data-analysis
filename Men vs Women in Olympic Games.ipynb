# %% [markdown]
# # Load data and python libraries

# %%
# %matplotlib inline 

# data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd 

# data visualization libraries
import matplotlib.pyplot as plt 
import seaborn as sns
import missingno

#supporting math libraries
import math
import numpy as np

# %%
input_folder = './data/'
output_folder = './output'

input_file = 'athlete_events.csv'

# %%
df_data = pd.read_csv(input_folder + input_file)
print("Data base size: ", len(df_data))
# Out:
# Data base size:  271116

# %% [markdown]
# # Dataset First Look

# %% [markdown]
# **The file athlete_events.csv contains 271116 rows and 15 columns. Each row corresponds to an individual athlete competing in an individual Olympic event (athlete-events). The columns are:**
#
# - **ID** - Unique number for each athlete
# - **Name** - Athlete's name
# - **Sex** - M or F
# - **Age** - Integer
# - **Height** - In centimeters
# - **Weight** - In kilograms
# - **Team** - Team name
# - **NOC** - National Olympic Committee 3-letter code
# - **Games** - Year and season
# - **Year** - Integer
# - **Season** - Summer or Winter
# - **City** - Host city
# - **Sport** - Sport
# - **Event** - Event
# - **Medal** - Gold, Silver, Bronze, or NA

# %%
#a quick look at the data
k = int(len(df_data)/5)
print("Data shape: ", df_data.shape)
print("View of every ", k, "observation:")
df_data.iloc[::k].T
# Out:
# Data shape:  (271116, 15)
# View of every  54223 observation:
#                              0                             54223   \
# ID                                1                         27817
# Name                      A Dijiang                 Lopold Desmet
# Sex                               M                             M
# Age                              24                            25
# Height                          180                           164
# Weight                           80                            70
# Team                          China                       Belgium
# NOC                             CHN                           BEL
# Games                   1992 Summer                   1960 Summer
# Year                           1992                          1960
# Season                       Summer                        Summer
# City                      Barcelona                          Roma
# Sport                    Basketball                    Gymnastics
# Event   Basketball Men's Basketball  Gymnastics Men's Horse Vault
# Medal                           NaN                           NaN
#
#                                     108446  \
# ID                                   54826
# Name                             Rei Jimbo
# Sex                                      F
# Age                                     26
# Height                                 164
# Weight                                  55
# Team                                 Japan
# NOC                                    JPN
# Games                          2000 Summer
# Year                                  2000
# Season                              Summer
# City                                Sydney
# Sport                Synchronized Swimming
# Event   Synchronized Swimming Women's Team
# Medal                               Silver
#
#                                           162669  \
# ID                                         81686
# Name                       William "Willi" Moore
# Sex                                            M
# Age                                           25
# Height                                       182
# Weight                                        67
# Team                               Great Britain
# NOC                                          GBR
# Games                                1972 Summer
# Year                                        1972
# Season                                    Summer
# City                                      Munich
# Sport                                    Cycling
# Event   Cycling Men's Team Pursuit, 4,000 metres
# Medal                                     Bronze
#
#                                 216892                271115
# ID                              108914                135571
# Name          Veronica Servente Tealdy    Tomasz Ireneusz ya
# Sex                                  F                     M
# Age                                 15                    34
# Height                             NaN                   185
# Weight                             NaN                    96
# Team                             Italy                Poland
# NOC                                ITA                   POL
# Games                      1992 Summer           2002 Winter
# Year                              1992                  2002
# Season                          Summer                Winter
# City                         Barcelona        Salt Lake City
# Sport                       Gymnastics             Bobsleigh
# Event   Gymnastics Women's Uneven Bars  Bobsleigh Men's Four
# Medal                              NaN                   NaN

# %%
#add new features
df_data['outcome'] = df_data['Medal'].isnull().apply(lambda x: "won a medal" if x == False else "NO medal")

# %%
#assumption: NaN="No medal" in the column "Medal"
df_data['Medal'] = df_data['Medal'].fillna('No medal')

# %%
#ID check
df_data.groupby('ID')['Name'].nunique().describe()
# Out:
# count    135571.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: Name, dtype: float64

# %%
#delete unnecessary  features
print("Delete ID column since each ID corresponds to unique Name")
df_data = df_data.drop('ID', axis=1)
# Out:
# Delete ID column since each ID corresponds to unique Name

# %%
print('there are ', len(df_data) - len(df_data.drop_duplicates()),' duplicated observations in the dataset.')

print("Dele duplicates:")
print(len(df_data))
df_data = df_data.drop_duplicates()
print(len(df_data))
# Out:
# there are  1385  duplicated observations in the dataset.
# Dele duplicates:
# 271116
# 269731

# %% [markdown]
# # Male vs. Female Athletes

# %%
# Interaction between pairs of features.
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.pairplot(df_data[['Age', 'Height', 'Weight', 'Sex']], 
             hue="Sex", 
             diag_kind="kde",
             size=4);
# Out:
# /Users/tatiana/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /Users/tatiana/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/tatiana/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
df_data.groupby('Sex')[['Age', 'Height', 'Weight']].describe().T
# Out:
# Sex                      F              M
# Age    count  73976.000000  186440.000000
#        mean      23.697713      26.151947
#        std        5.695049       6.203904
#        min       11.000000      10.000000
#        25%       20.000000      22.000000
#        50%       23.000000      25.000000
#        75%       27.000000      29.000000
#        max       74.000000      97.000000
# Height count  67378.000000  143539.000000
#        mean     167.839740     178.859125
#        std        8.778528       9.360033
#        min      127.000000     127.000000
#        25%      162.000000     172.000000
#        50%      168.000000     179.000000
#        75%      173.000000     185.000000
#        max      213.000000     226.000000
# Weight count  66771.000000  141433.000000
#        mean      60.021252      75.744091
#        std       10.212250      13.213003
#        min       25.000000      28.000000
#        25%       54.000000      67.000000
#        50%       59.000000      74.000000
#        75%       65.000000      83.000000
#        max      167.000000     214.000000

# %% [markdown]
# ##### Observations:
#
# - on average female athletes are 3 years younger, 11 centimeters shorter and have 15 kilograms smaller weight
# - similar to male athletes, female athletes have higher weight when they are taller

# %% [markdown]
# ### Age distribution

# %%
g = sns.catplot(x="Year", y="Age", hue="Sex", 
            palette='pastel', split=True, legend_out=False,
            kind="violin", data=df_data, height=7, aspect=2.5);

g.set_xticklabels(rotation=30)

g.fig.suptitle("Age Distribution by Year", fontsize=18)
g.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)

# %%
df_tmp = pd.DataFrame(df_data.groupby(['Year', 'Sex'])['Age'].median()).reset_index()

sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2})
g = sns.relplot(x="Year", y="Age", kind="line",hue='Sex', data=df_data, height=7, aspect=2)

g.fig.suptitle("Age by Year\nmean and the 95% confidence interval around the mean", fontsize=18)
# Out:
# Text(0.5, 0.98, 'Age by Year\nmean and the 95% confidence interval around the mean')

# %%
print ("Sports with athletes older than 50")
age_ge50 = df_data[df_data['Age'] > 50]
ts = age_ge50['Sport'].value_counts()
ts
# Out:
# Sports with athletes older than 50
# Art Competitions     560
# Shooting             380
# Equestrianism        247
# Sailing              143
# Archery               66
# Fencing               40
# Rowing                 9
# Bobsleigh              5
# Alpine Skiing          3
# Curling                3
# Croquet                2
# Luge                   2
# Roque                  2
# Speed Skating          2
# Table Tennis           2
# Skeleton               2
# Polo                   2
# Modern Pentathlon      1
# Diving                 1
# Figure Skating         1
# Motorboating           1
# Alpinism               1
# Athletics              1
# Name: Sport, dtype: int64

# %%
top_5_age_ge50 = age_ge50[age_ge50['Sport'].isin(list(ts.index)[:5])]
print('Number of athletes older than 50:\n', top_5_age_ge50.groupby(['Sex'])['Age'].count(), '\n\n')
top_5_age_ge50.groupby(['Sport', 'Sex'])['Age'].describe()
# Out:
# Number of athletes older than 50:
#  Sex
# F     144
# M    1252
# Name: Age, dtype: int64
#                       count       mean       std   min    25%   50%   75%  \
# Sport            Sex
# Archery          F     12.0  57.666667  3.797926  53.0  54.75  58.0  60.0
#                  M     54.0  57.370370  5.122265  51.0  54.00  56.0  61.0
# Art Competitions F     54.0  60.240741  6.870597  51.0  54.00  59.5  65.0
#                  M    506.0  59.608696  7.160469  51.0  54.00  58.0  64.0
# Equestrianism    F     60.0  55.416667  4.738203  51.0  52.00  53.5  58.0
#                  M    187.0  55.133690  4.363619  51.0  52.00  54.0  57.0
# Sailing          M    143.0  55.811189  4.732196  51.0  52.00  55.0  59.0
# Shooting         F     18.0  53.000000  1.814970  51.0  52.00  52.0  54.0
#                  M    362.0  55.038674  4.118554  51.0  52.00  54.0  57.0
#
#                        max
# Sport            Sex
# Archery          F    63.0
#                  M    71.0
# Art Competitions F    74.0
#                  M    97.0
# Equestrianism    F    69.0
#                  M    72.0
# Sailing          M    71.0
# Shooting         F    57.0
#                  M    72.0

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})

sns.catplot(x="Age", y="Sport", hue="Sex",
            kind="box",
            palette="pastel",  height=5, aspect=7/5,
            data=top_5_age_ge50)

# %% [markdown]
# ##### Observations:
#
# - beginning from 1992 female and male athletes have similar age distribution, although females are still few years younger in general
# - there are almost 9 times more males than females among athletes with age above 50
# - The oldest athletes among female (74 year old) and among male (97 year old) compete in Art Competitions

# %% [markdown]
# ### Age of Athletes with Medals

# %%
df_medals = df_data[df_data['Medal'].isnull() == False]

df_medals.groupby(['Medal', 'Sex'])['Age'].describe()
# Out:
#                  count       mean       std   min   25%   50%   75%   max
# Medal    Sex
# Bronze   F      3763.0  24.708743  5.334748  12.0  21.0  24.0  28.0  69.0
#          M      9243.0  26.355729  5.957346  10.0  22.0  25.0  29.0  72.0
# Gold     F      3744.0  24.372596  5.221598  13.0  21.0  24.0  27.0  63.0
#          M      9478.0  26.503376  6.032284  13.0  22.0  25.0  29.0  64.0
# No medal F     62740.0  23.552391  5.755343  11.0  19.0  23.0  27.0  74.0
#          M    158632.0  26.091911  6.227382  11.0  22.0  25.0  29.0  97.0
# Silver   F      3729.0  24.444891  5.257146  11.0  21.0  24.0  27.0  55.0
#          M      9087.0  26.626169  6.179563  13.0  23.0  26.0  29.0  73.0

# %%
df_medals[(df_medals['Age'] < 14) & 
          (df_medals['Medal'] != 'No medal')][['Year', 'Sex', 'Sport', 'Medal']].sort_values(by=[
                                                                                            'Year','Medal','Sex'])
# Out:
#         Year Sex                      Sport   Medal
# 142882  1896   M                 Gymnastics  Bronze
# 200704  1920   F                     Diving    Gold
# 222373  1920   M                     Diving  Silver
# 27207   1928   M                     Rowing    Gold
# 79024   1928   F                 Gymnastics  Silver
# 148942  1928   F                 Gymnastics  Silver
# 192507  1928   F                     Diving  Silver
# 236378  1928   F                 Gymnastics  Silver
# 251495  1928   F                 Gymnastics  Silver
# 206759  1936   F                   Swimming  Bronze
# 226019  1936   F                   Swimming  Bronze
# 249803  1936   M                     Rowing  Bronze
# 249804  1936   M                     Rowing  Bronze
# 78544   1936   F                     Diving    Gold
# 52010   1960   F                   Swimming    Gold
# 268602  1960   M                     Rowing    Gold
# 63524   1972   F                   Swimming  Silver
# 63525   1972   F                   Swimming  Silver
# 63526   1972   F                   Swimming  Silver
# 44972   1976   F                   Swimming  Bronze
# 73581   1992   F                     Diving    Gold
# 80827   1992   F                 Gymnastics  Silver
# 119277  1994   F  Short Track Speed Skating    Gold
# 170652  1996   F                   Swimming  Silver

# %%
g = sns.catplot(x="Medal", y="Age", hue="Sex", 
            palette='pastel', legend_out=False, k_depth="proportion",
            kind="boxen", data=df_medals,  height=5, aspect=7/5,)

g.fig.suptitle("Age Distribution of Athletes  with Medals", fontsize=18)
g.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25),
          fancybox=True, shadow=True, ncol=5)

# %%
#collecting data to calculate  probability to have a medal at a certain age
df_tmp = pd.DataFrame(df_data.groupby(['Sex', 'Age', 'Medal'])['Name'].count()).reset_index()

# %%
#defining ages with 3 medals for any gender
df_test = df_tmp.groupby(['Sex', 'Age'])['Medal'].count() # 'No medal' is the 4th value in the column
df_test[df_test == 4].reset_index().describe().T
# Out:
#        count       mean        std   min    25%   50%    75%   max
# Age     82.0  34.231707  13.107626  13.0  23.25  33.5  43.75  63.0
# Medal   82.0   4.000000   0.000000   4.0   4.00   4.0   4.00   4.0

# %%
#considering only ages with 3 medals for any gender
df_tmp = df_tmp[(df_tmp['Age'] > 13) & (df_tmp['Age'] < 45)]

df_tmp['total'] = df_tmp.groupby(['Sex', 'Age'])['Name'].transform('sum')

df_tmp['chance to have in %'] = df_tmp['Name'] / df_tmp['total'] * 100
df_tmp = df_tmp[df_tmp['Medal'] != 'No medal']
df_tmp['Age'] = df_tmp['Age'].apply(int)
df_tmp.head()
# Out:
#    Sex  Age   Medal  Name  total  chance to have in %
# 9    F   14  Bronze    15    744             2.016129
# 10   F   14    Gold    20    744             2.688172
# 12   F   14  Silver    25    744             3.360215
# 13   F   15  Bronze    51   1911             2.668760
# 14   F   15    Gold    66   1911             3.453689

# %%
df_tmp_M = df_tmp[df_tmp['Sex'] == 'M']

sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2})

g = sns.catplot(x="Age", y="chance to have in %", hue="Medal",
            palette={"Gold": "gold", "Silver": "silver", "Bronze": "goldenrod"},
            legend=False,
            kind="point", data=df_tmp_M, height=7, aspect=25/7)

g.set_xticklabels(rotation=30)

g.fig.suptitle("Chance to Have a Medal (in %) by Age\nfor  Male", fontsize=30)
g.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)

# %%
df_tmp_F = df_tmp[df_tmp['Sex'] == 'F']

sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2})

g = sns.catplot(x="Age", y="chance to have in %", hue="Medal",
            palette={"Gold": "gold", "Silver": "silver", "Bronze": "goldenrod"},
            legend=False,
            kind="point", data=df_tmp_M, height=7, aspect=25/7)

g.set_xticklabels(rotation=30)
                
g.set_xticklabels(rotation=30)

g.fig.suptitle("Chance to Have a Medal (in %) by Age\nfor  Femails", fontsize=30)
g.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)

# %% [markdown]
# ##### Observations:
#
# - on average male medalists are 2 years older than female medalists
# - the youngest medalists are 10-13 year old, were winning in the period 1896-1996 and in the last 8 games were females
# - after 1996 medalists became older
# - both women and men are at the picks of their performance in their middle 20s.
# - although chances to win a medal start to decline at the end of thirties from around 6% nearing 4%, women can perform as strong as their middle 20s in their after 40s in such sports as Equestrianism, Curling and Archery.
# - men's chances to win a medal has very little change from its pick in the 20s second half

# %% [markdown]
# ### Number of athletes by year

# %%
plt.style.use('seaborn-whitegrid')

sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

season = 'Winter'
df_tmp = df_data[df_data['Season'] == season]
g = sns.catplot(x="Year", hue="Sex", 
            palette='pastel', legend_out=False,
            kind="count", data=df_tmp, height=5, aspect=4)

g.set_xticklabels(rotation=30)

g.fig.suptitle("Number of Athletes by Year\n Season: " + season, fontsize=18, y=1.05)
g.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),
          fancybox=True, shadow=True, ncol=5)



season = 'Summer'
df_tmp = df_data[df_data['Season'] == season]
g = sns.catplot(x="Year", hue="Sex",
            palette='pastel', legend_out=False,
            kind="count", data=df_tmp, height=5, aspect=4)

g.set_xticklabels(rotation=30)

g.fig.suptitle("Number of Athletes by Year\n Season: " + season, fontsize=18, y=1.05)
g.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),
          fancybox=True, shadow=True, ncol=5)

# %% [markdown]
# ##### Observations:
#
# - although number of male athletes each year both seasons more or less stabilized after 1988,
#   number of female athletes is still growing
